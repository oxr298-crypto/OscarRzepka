# %% [markdown]
# <a href="https://colab.research.google.com/github/oxr298-crypto/OscarRzepka/blob/main/In_Class_Assignments_BTE_320.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Sales = float(input("Enter the total sales: "))

COGS = .4 * Sales
GP = Sales - COGS

print(f"Sales: {Sales}$")
print(f"Cost of Goods Sold: {COGS}$")
print(f"Gross Profit: {GP}$")
# Out:
# Enter the total sales: 12000
# Sales: 12000.0$
# Cost of Goods Sold: 4800.0$
# Gross Profit: 7200.0$

# %%
email = " Urgent! open this link: https://www.spam.org to recieve your award!!!"
is_urgent = "Urgent"
has_www = "www."

if is_urgent in email:
  print("Phising!")
elif has_www in email:
  print("Spam")
else:
  print("Legit")
# Out:
# Phising!

# %%
grade = float(input("Enter your grade: "))

if grade >= 97:
  print("A+")
elif grade >= 93:
  print("A")
elif grade >= 90:
  print("A-")
# Out:
# Enter your grade: 90
# A-

# %%
email = "Urgent! Click on the follwoing link www.phis.org to...."
is_urgent = "Urgent"
has_www = "www"
if is_urgent in email:
  if has_www in email:
    print("Phishing")
  else:
    print("Spam")
else:
  print("Legit")

# %%
email = "Urgent! CLick on the following to..."
is_urgent = "Urgent"
has_www = "www"

if is_urgent in email and has_www in email:
  print("Phishing")
elif is_urgent in email:
  print("Spam")


if not is_urgent in email and not has_www in email:
  print("Legit")
# Out:
# Spam
